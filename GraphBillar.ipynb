# %%
using PyPlot

# %%
y=2
# Out:
# 2

# %%
plot([0,1],[1,1],linestyle="-",linewidth=3.0)
plot([0,1],[-1,-1],linestyle="-",linewidth=3.0)

y=linspace(-10,10,10000000);
x1=sqrt.(complex(100.0-y.^2 ));

plot(x1,y)
ylim(-10,10)

axes()[:set_xlim]([-1,2])
axes()[:set_ylim]([-2,2])

show()
# Out:
# PyPlot.Figure(PyObject <matplotlib.figure.Figure object at 0x7fdc87c70810>)
# /usr/local/lib/python2.7/dist-packages/numpy/core/numeric.py:531: ComplexWarning: Casting complex values to real discards the imaginary part
#   return array(a, dtype, copy=False, order=order)

# %%
m=0.0000000000000000000000000000000000000000000000001
# Out:
# 1.0e-49

# %%
y1=linspace(-10,10,10000000);
y2=linspace(-20,0,10000000);
x1=sqrt.(complex(100.0-y1.^2 ));
x2=m*y2+10
#x3=
# Out:
# 10000000-element LinSpace{Float64}:
#  10.0,10.0,10.0,10.0,10.0,10.0,10.0,10.0,…,10.0,10.0,10.0,10.0,10.0,10.0,10.0

# %%
plot(x1,y1)
plot(y2,x2)
ylim(0,20)
ylabel("y")
xlabel("x")
show();
# Out:
# PyPlot.Figure(PyObject <matplotlib.figure.Figure object at 0x7ff13c039290>)
# /usr/local/lib/python2.7/dist-packages/numpy/core/numeric.py:531: ComplexWarning: Casting complex values to real discards the imaginary part
#   return array(a, dtype, copy=False, order=order)
