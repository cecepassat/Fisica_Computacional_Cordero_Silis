# %%
using PyPlot

# %%
x=linspace(-1,1,1000);
for i in 1:1000
    y[i]=sqrt(1-x[i]*x[i])+1;
end

# %%
plot(x,y,color="#000000")
plot(x,-y,color="#000000")
plot([-1,-1],[-1,1],color="#000000")
plot([1,1],[-1,1],color="#000000")
xlim(-3,3)
ylim(-3,3)
# Out:
# PyPlot.Figure(PyObject <matplotlib.figure.Figure object at 0x7f9eecc3e810>)
# (-3,3)
